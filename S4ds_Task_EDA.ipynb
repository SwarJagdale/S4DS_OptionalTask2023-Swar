# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Amazon_Products_clean.csv")

# %%
df.shape
# Out:
# (10002, 15)

# %%
df.skew()
# Out:
# manufacturer                    0.776464
# price                           0.872411
# number_available_in_stock       2.962398
# number_of_reviews               2.346462
# number_of_answered_questions    7.820505
# average_review_rating          -0.943892
# dtype: float64

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr()
# Out:
#                               manufacturer     price  \
# manufacturer                      1.000000 -0.069945
# price                            -0.069945  1.000000
# number_available_in_stock        -0.127503  0.029244
# number_of_reviews                 0.003061 -0.031020
# number_of_answered_questions     -0.020644 -0.015054
# average_review_rating             0.003997  0.046168
#
#                               number_available_in_stock  number_of_reviews  \
# manufacturer                                  -0.127503           0.003061
# price                                          0.029244          -0.031020
# number_available_in_stock                      1.000000           0.216214
# number_of_reviews                              0.216214           1.000000
# number_of_answered_questions                   0.016379           0.108063
# average_review_rating                         -0.020077          -0.111232
#
#                               number_of_answered_questions  \
# manufacturer                                     -0.020644
# price                                            -0.015054
# number_available_in_stock                         0.016379
# number_of_reviews                                 0.108063
# number_of_answered_questions                      1.000000
# average_review_rating                            -0.025725
#
#                               average_review_rating
# manufacturer                               0.003997
# price                                      0.046168
# number_available_in_stock                 -0.020077
# number_of_reviews                         -0.111232
# number_of_answered_questions              -0.025725
# average_review_rating                      1.000000

# %% [markdown]
# ## Correlation of Number available in stock with Number of Reviews
#     This shows a slight positive correlation between the number of products available in stock with the number of reviews.
#     Products with more availability tend to have more reviews

# %% [markdown]
# ## Correlation between number of reviews and average review rating:
#     There is a slight negative correlation (-0.111) between the number of reviews and the average review rating. This suggests a weak relationship where products with more reviews might have slightly lower average review ratings.

# %% [markdown]
# # Price Analysis
# ##  Distribution of price

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.boxplot(df.price,whis=1.5)
plt.show()

# %% [markdown]
#     The top 5 manufacturers with the most number of products are:
#     LEGO-275
#     Disney-94
#     Oxford Diecast-342
#     Playmobil-268
#     Star Wars-90

# %%
no_of_prod=df.groupby('manufacturer')['product_name'].count().sort_values(ascending=False)

# %%
no_of_prod
# Out:
# manufacturer
# 275.0     171
# 94.0      167
# 342.0     156
# 268.0     147
# 90.0      120
#          ...
# 1275.0      1
# 1273.0      1
# 1269.0      1
# 1264.0      1
# 2652.0      1
# Name: product_name, Length: 2652, dtype: int64

# %%
g = sns.catplot(x="manufacturer",data=df, kind="count",height=6,  order = df['manufacturer'].value_counts()[:90].index.tolist())
g.set_xticklabels(['LEGO', 'Disney', 'Oxford Diecast', 'Playmobil', 'Star Wars'],rotation=90)

# %% [markdown]
# ### Distribution of Price in LEGO

# %%
df[(df['manufacturer']==275)].price.skew()
# Out:
# 0.3400881548603544

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['manufacturer']==275)], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of LEGO')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Distribution of Price in Disney

# %%
df[(df['manufacturer']==94)].price.skew()
# Out:
# 0.800326382998095

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['manufacturer']==94)], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Disney')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Distribution of Price of Oxford Diecast

# %%
df[(df['manufacturer']==342)].price.skew()
# Out:
# 0.9427472373936285

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['manufacturer']==342)], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Oxford Diecast')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Distribution of Price of Playmobil

# %%
df[(df['manufacturer']==268)].price.skew()
# Out:
# 0.6120347163785925

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['manufacturer']==268)], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Playmobil')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Distribution of Price of Star Wars

# %%
df[(df['manufacturer']==90)].price.skew()
# Out:
# 0.7413294942595983

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['manufacturer']==90)], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Star Wars')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %%
df2=pd.read_csv('Amazon_category.csv')

# %%
df3=pd.read_csv("Amazon_subcategory.csv")

# %%
df2=df2.sort_values(by='frequency',ascending=False)

# %%
df2[:16].sum()
# Out:
# category     HobbiesDie-Cast & Toy VehiclesFigures & Playse...
# frequency                                               9245.0
# dtype: object

# %%
fig, ax = plt.subplots(figsize=(16, 8))  # Set the width to 10 inches
ax.bar(df2.head().category, df2.head().frequency.values)
ax.set_title(f'Top 5 categories')
ax.set_xlabel('Category')
ax.set_ylabel('Items Present')
# Out:
# Text(0, 0.5, 'Items Present')

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['category']=='Hobbies')], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Hobbies')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['category']=='Die-Cast & Toy Vehicles')], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Die-Cast & Toy Vehicles')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['category']=='Figures & Playsets')], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Figures & Playsets')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['category']=='Characters & Brands')], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Characters & Brands')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df[(df['category']=='Games')], x='price', bins=20, kde=True, color='blue')
plt.title('Distribution of Price of Games')
plt.xlabel('Price ')
plt.ylabel('Frequency')
plt.show()

# %%
df
# Out:
#                                 uniq_id  \
# 0      eac7efa5dbd3d667f26eb3d3ab504464
# 1      b17540ef7e86e461d37f3ae58b7b72ac
# 2      348f344247b0c1a935b1223072ef9d8a
# 3      e12b92dbb8eaee78b22965d2a9bbbd9f
# 4      e33a9adeed5f36840ccc227db4682a36
# ...                                 ...
# 9997   44d6967f083825a5de36ad4865a65bcd
# 9998   08f0747b6fc6687215ffb994c3a6fb32
# 9999   bf6cc073f8f24e6e338190fa16f6ee9d
# 10000  cd783d0b8b44e631b9788b203eaaefae
# 10001  94d18e86e504bee1e392df7e5738b18a
#
#                                             product_name  manufacturer  \
# 0                                  Hornby 2014 Catalogue           0.0
# 1      FunkyBuys® Large Christmas Holiday Express Fes...           1.0
# 2      CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...           2.0
# 3         HORNBY Coach R4410A BR Hawksworth Corridor 3rd           0.0
# 4      Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...           0.0
# ...                                                  ...           ...
# 9997   Batman 1966 TV Series Action Figures - The Rid...          31.0
# 9998   Star Wars Costume, Kids Stormtrooper Costume S...          90.0
# 9999         Defiance Lawkeeper Metal Badge Prop Replica        2359.0
# 10000  Justice League of America Series 3 Green Lante...         180.0
# 10001                  Star Wars 1/72 Y-Wing Starfighter          43.0
#
#            price  number_available_in_stock  number_of_reviews  \
# 0       3.400000                        5.0               15.0
# 1      16.900000                        0.0                2.0
# 2       9.900000                        2.0               17.0
# 3      39.900000                        0.0                1.0
# 4      32.100000                        0.0                3.0
# ...          ...                        ...                ...
# 9997   22.900000                        5.0                3.0
# 9998   39.900000                        0.0                1.0
# 9999   41.703298                        3.0                1.0
# 10000  41.703298                        3.0                1.0
# 10001  21.200000                       31.0               11.0
#
#        number_of_answered_questions  average_review_rating  \
# 0                               1.0                    4.9
# 1                               1.0                    4.5
# 2                               2.0                    3.9
# 3                               2.0                    5.0
# 4                               2.0                    4.7
# ...                             ...                    ...
# 9997                            3.0                    5.0
# 9998                            3.0                    4.0
# 9999                            3.0                    5.0
# 10000                           3.0                    5.0
# 10001                           3.0                    4.5
#
#                         amazon_category_and_sub_category  \
# 0      ['Hobbies', 'Model Trains & Railway Sets', 'Ra...
# 1      ['Hobbies', 'Model Trains & Railway Sets', 'Ra...
# 2      ['Hobbies', 'Model Trains & Railway Sets', 'Ra...
# 3      ['Hobbies', 'Model Trains & Railway Sets', 'Ra...
# 4      ['Hobbies', 'Model Trains & Railway Sets', 'Ra...
# ...                                                  ...
# 9997   ['Hobbies', 'Collectible Figures & Memorabilia...
# 9998        ['Characters & Brands', 'Star Wars', 'Toys']
# 9999   ['Novelty & Special Use', 'Novelty', 'Accessor...
# 10000  ['Hobbies', 'Collectible Figures & Memorabilia...
# 10001       ['Characters & Brands', 'Star Wars', 'Toys']
#
#                                              description  \
# 0      Product Description Hornby 2014 Catalogue Box ...
# 1      Size Name:Large FunkyBuys® Large Christmas Hol...
# 2      BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3      Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4      Product Description Hornby RailRoad 0-4-0 Gild...
# ...                                                  ...
# 9997   DC 66 Batman Classic TV Series 6 Inch Riddler ...
# 9998                                                 NaN
# 9999   *Includes 1x Badge with holder and chain *High...
# 10000  Designed by Ed BenesIt's here - the third seri...
# 10001                                                NaN
#
#                                      product_information  \
# 0      Technical Details Item Weight640 g Product Dim...
# 1      Technical Details Manufacturer recommended age...
# 2      Technical Details Manufacturer recommended age...
# 3      Technical Details Item Weight259 g Product Dim...
# 4      Technical Details Item Weight159 g Product Dim...
# ...                                                  ...
# 9997   Technical Details Item Weight136 g Product Dim...
# 9998   Technical Details    Additional Information AS...
# 9999   Technical Details Item Weight159 g Product Dim...
# 10000  Technical Details Item Weight181 g Product Dim...
# 10001  Technical Details Item Weight299 g Product Dim...
#
#                                      product_description  \
# 0      Product Description Hornby 2014 Catalogue Box ...
# 1      Size Name:Large FunkyBuys® Large Christmas Hol...
# 2      BIG CLASSIC TOY TRAIN SET TRACK CARRIAGE LIGHT...
# 3      Hornby 00 Gauge BR Hawksworth 3rd Class W 2107...
# 4      Product Description Hornby RailRoad 0-4-0 Gild...
# ...                                                  ...
# 9997   DC 66 Batman Classic TV Series 6 Inch Riddler ...
# 9998                                                 NaN
# 9999   *Includes 1x Badge with holder and chain *High...
# 10000  Designed by Ed BenesIt's here - the third seri...
# 10001                                                NaN
#
#              items_customers_buy_after_viewing_this_item  \
# 0      http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1      http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2      http://www.amazon.co.uk/Train-With-Tracks-Batt...
# 3                                                    NaN
# 4      http://www.amazon.co.uk/Hornby-R2672-RailRoad-...
# ...                                                  ...
# 9997                                                 NaN
# 9998   http://www.amazon.co.uk/Storm-Trooper-Costume-...
# 9999   http://www.amazon.co.uk/Olde-Scotland-Yard-Ltd...
# 10000                                                NaN
# 10001                                                NaN
#
#                     category                        subcategory
# 0                    Hobbies        Model Trains & Railway Sets
# 1                    Hobbies        Model Trains & Railway Sets
# 2                    Hobbies        Model Trains & Railway Sets
# 3                    Hobbies        Model Trains & Railway Sets
# 4                    Hobbies        Model Trains & Railway Sets
# ...                      ...                                ...
# 9997                 Hobbies  Collectible Figures & Memorabilia
# 9998     Characters & Brands                          Star Wars
# 9999   Novelty & Special Use                            Novelty
# 10000                Hobbies  Collectible Figures & Memorabilia
# 10001    Characters & Brands                          Star Wars
#
# [10002 rows x 15 columns]
